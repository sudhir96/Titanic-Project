# %%
import pandas as pd
import numpy as np
df=pd.read_csv("D://Titanic_project//train.csv", dtype={"Age": np.float64},)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_df=pd.read_csv("D://Titanic_project//test.csv", dtype={"Age": np.float64},)
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# df['Age']=df['Age'].fillna(df.Age.median())

# %%
# test=pd.get_dummies(df1,columns=['Embarked','Sex','Pclass'],prefix_sep='_',drop_first=False)

# %% [markdown]
# # Feature_Engineering of Name

# %%
df["title"] = [i.split('.')[0] for i in df.Name]
df["title"] = [i.split(',')[1] for i in df.title]

# %%
df['title']=[i.replace('Mlle','Miss') for i in df['title']]
df['title']=[i.replace('Mme','Mrs') for i in df['title']]
df['title']=[i.replace('Ms','Miss') for i in df['title']]
df['title']=[i.replace('Dr','royal') for i in df['title']]
df['title']=[i.replace('Lady','royal') for i in df['title']]
df['title']=[i.replace('Sir','royal') for i in df['title']]
df['title']=[i.replace('Don','royal') for i in df['title']]
df['title']=[i.replace('Major','royal') for i in df['title']]
df['title']=[i.replace('Master','royal') for i in df['title']]
df['title']=[i.replace('Capt','royal') for i in df['title']]
df['title']=[i.replace('Rev','rare') for i in df['title']]
df['title']=[i.replace('Col','rare') for i in df['title']]
df['title']=[i.replace('the Countess','rare') for i in df['title']]
df['title']=[i.replace('Jonkheer','rare') for i in df['title']]

# %% [markdown]
# ## Cleaning & Feature_Engineering of Age

# %%
# Finding the missing values in titanic data set what we get is that their is maximum missing value in cabin as well as Age.
centage=(df.isnull().sum())*100/len(df)
centage
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# title           0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.style.use ('classic')
# %matplotlib inline

# %%
# import seaborn as sns 
# sns.violinplot(df['Age'], df['Survived']) #Variable Plot
# sns.despine()

# %%
msno.heatmap(df)
# this is heatmap of all the varible we have,it represents that the varible which have lesser value of correlation means less correlated
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-9e3c89a17231> in <module>()
# ----> 1 msno.heatmap(df)
#       2 # this is heatmap of all the varible we have,it represents that the varible which have lesser value of correlation means less correlated
#
# NameError: name 'msno' is not defined

# %%
df.describe()

# %%
df.info()

# %%
df2=df.drop(['Ticket','Name'],axis=1)

# %%
df2['Embarked'].replace('nan','S',inplace=True)

# %%
data=df2.drop([ 'Cabin'],axis=1)

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
#
#   Embarked title  Family_Group Family_Category  Group_fare Size_fare  \
# 0        S    Mr             2           Small     3.62500  Very_low
# 1        C   Mrs             2           Small    35.64165      High
#
#   Age_Category
# 0        Adult
# 1        Adult

# %%
# from sklearn.linear_model import LinearRegression
# # lineareg = LinearRegression()

# %%
# y=data['Age']
# X=data.drop(['Age'],axis=1)

# %%
# lineareg.fit(X,y)

# %%
# test_data=X
# age_predicted=pd.DataFrame(lineareg.predict(test_data))

# %%
# Predicted_Age1=pd.DataFrame(age_predicted)

# %%
# columns=['Predicted_Age1']
# Predicted_Age1.columns = columns
# Predicted_Age1.head()

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
#
#   Embarked title
# 0        S    Mr
# 1        C   Mrs

# %%
# import numpy as np
# bins=[-3,0,5,13,20,60,np.inf]
# labels=['Unborn','Baby','Child','Young_Adult','Adult','Senior_citizen']
# data1['Age_Category']=pd.cut(data1['Predicted_Age1'],bins,labels=labels)

# %%
# A=[]
# for i in range(0,len(data1.Predicted_Age1)):
#     if data1.Predicted_Age1[i]>=13:
#         A.append('Adult')
#     else :
#          A.append('Child')
# data1['person']=pd.DataFrame(A)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  title
# 0        S     Mr
# 1        C    Mrs
# 2        S   Miss
# 3        S    Mrs
# 4        S     Mr

# %% [markdown]
# ## Family_Group

# %%
data['Family_Group']=data.Parch+data.SibSp+1

# %%
def Family_Size(Group):
    A=''
    if (Group<=1):
        A='Alone'
    elif (Group<=4):
            A='Small'
    else :
                A='Large'
    return A

# %%
data['Family_Category']=data['Family_Group'].map(Family_Size)

# %%
data['Group_fare']=data['Fare']/data['Family_Group']

# %%
def total_fare(fare):
    x=''
    if (fare<5):
        x='Very_low'
    elif (fare<10):
        x='Low'
    elif (fare<=20):
        x='Medium'
    elif (fare<=45):
        x='High'
    else:
        x='Very_high'
    return x

# %%
data['Size_fare']=data['Group_fare'].map(total_fare)

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
#
#   Embarked title  Family_Group Family_Category  Group_fare Size_fare
# 0        S    Mr             2           Small     3.62500  Very_low
# 1        C   Mrs             2           Small    35.64165      High

# %% [markdown]
# ## Imputing_Age using GradientBoost

# %%
# X1=data1.drop(['Parch','SibSp','Age','Fare'],axis=1)
# Y1=data1['Age']

# %%
# from sklearn import ensemble
# from sklearn.ensemble import GradientBoostingRegressor
# model=ensemble.GradientBoostingRegressor()
# model.fit(X1,Y1)

# %%
# test_data=X1
# data1['Age_predicted']=pd.DataFrame(model.predict(test_data))

# %%
# for dataset in combine:
#     for i in range(0, 2):
#         for j in range(0, 3):
#             guess_df = dataset[(dataset['Sex'] == i) & \
#                                   (dataset['Pclass'] == j+1)]['Age'].dropna()

#             # age_mean = guess_df.mean()
#             # age_std = guess_df.std()
#             # age_guess = rnd.uniform(age_mean - age_std, age_mean + age_std)

#             age_guess = guess_df.median()

#             # Convert random age float to nearest .5 age
#             guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
#     for i in range(0, 2):
#         for j in range(0, 3):
#             dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
#                     'Age'] = guess_ages[i,j]

#     dataset['Age'] = dataset['Age'].astype(int)

# train_df.head()

# %%
# data['Age']=data['Age'].fillna(0)

# %%
data['Age']=data.Age.astype(float)

# %%
df=pd.DataFrame(data.groupby('title',as_index=False)['Age'].mean())
df
# Out:
#     title        Age
# 0    Miss  21.845638
# 1      Mr  32.368090
# 2     Mrs  35.788991
# 3    rare  44.600000
# 4   royal  15.013958

# %%
data['Age']=data.groupby('title')['Age'].transform(lambda x: x.fillna(x.mean()))

# %%
data['Survived'].groupby(pd.qcut(data['Age'],5)).mean()
# Out:
# Age
# (0.419, 20.0]     0.456522
# (20.0, 26.0]      0.397727
# (26.0, 32.368]    0.272358
# (32.368, 38.0]    0.509259
# (38.0, 80.0]      0.372881
# Name: Survived, dtype: float64

# %%
import numpy as np
bins=[0,5,14,19,38,55,np.inf]
labels=['Baby','Child','Junior_Adult','Adult','Senior_Adult','Senior_Citizen']
data['Age_Category']=pd.cut(data['Age'],bins,labels=labels)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  title  Family_Group Family_Category  Group_fare Size_fare  \
# 0        S     Mr             2           Small     3.62500  Very_low
# 1        C    Mrs             2           Small    35.64165      High
# 2        S   Miss             1           Alone     7.92500       Low
# 3        S    Mrs             2           Small    26.55000      High
# 4        S     Mr             1           Alone     8.05000       Low
#
#   Age_Category
# 0        Adult
# 1        Adult
# 2        Adult
# 3        Adult
# 4        Adult

# %%
data1=pd.get_dummies(data.drop(['Age','PassengerId','Parch','Family_Group','SibSp','Fare'],axis=1),columns=['Age_Category','Sex','Pclass','title','Embarked','Family_Category','Size_fare'],prefix_sep='_',drop_first=False)

# %%
data1.head()
# Out:
#    Survived  Group_fare  Age_Category_Baby  Age_Category_Child  \
# 0         0     3.62500                  0                   0
# 1         1    35.64165                  0                   0
# 2         1     7.92500                  0                   0
# 3         1    26.55000                  0                   0
# 4         0     8.05000                  0                   0
#
#    Age_Category_Junior_Adult  Age_Category_Adult  Age_Category_Senior_Adult  \
# 0                          0                   1                          0
# 1                          0                   1                          0
# 2                          0                   1                          0
# 3                          0                   1                          0
# 4                          0                   1                          0
#
#    Age_Category_Senior_Citizen  Sex_female  Sex_male         ...          \
# ...

# %% [markdown]
# ## Test_data_work

# %% [markdown]
# ### Missing_values_treatment_Age

# %%
test_df.head(2)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked title  Family_Group Family_Category  \
# 0      0  330911  7.8292   NaN        Q    Mr             1           Alone
# 1      0  363272  7.0000   NaN        S   Mrs             2           Small
#
#    Group_Fare Size_fare  Age_Category
# 0      7.8292       Low         Adult
# 1      3.5000  Very_low  Senior_Adult

# %% [markdown]
# ### Missing_values_treatment_Fare

# %%
test_df['Fare']=test_df['Fare'].fillna(test_df.Fare.mean())

# %% [markdown]
# ### Feature_Engineering_Name

# %%
test_df['title']=[i.split('.')[0] for i in test_df['Name']]
test_df['title']=[i.split(',')[1] for i in test_df['title']]

# %%
test_df['title']=[i.replace('Ms','Miss') for i in test_df['title']]
test_df['title']=[i.replace('Dr','royal') for i in test_df['title']]
test_df['title']=[i.replace('Rev','rare') for i in test_df['title']]
test_df['title']=[i.replace('Col','rare') for i in test_df['title']]
test_df['title']=[i.replace('Dona','rare') for i in test_df['title']]
test_df['title']=[i.replace('Master','royal') for i in test_df['title']]

# %%
test_df['Family_Group']=test_df.Parch+test_df.SibSp+1

# %%
def Family_Size(Group):
    B=''
    if (Group<=1):
        B='Alone'
    elif (Group<=4):
        B='Small'
    else:
        B='Large'
    return B

# %%
test_df['Family_Category']=test_df['Family_Group'].map(Family_Size)

# %%
test_df['Group_Fare']=test_df['Fare']/test_df['Family_Group']

# %%
def total_fare(fare):
    C=''
    if (fare<5):
        C='Very_low'
    elif (fare<10):
        C='Low'
    elif (fare<=20):
        C='Medium'
    elif (fare<=45):
        C='Large'
    else:
        C='Very_high'
    return C

# %%
test_df['Size_fare']=test_df['Group_Fare'].map(total_fare)

# %%
test_df.Embarked.value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked title  Family_Group  \
# 0  34.5      0      0   330911   7.8292   NaN        Q    Mr             1
# 1  47.0      1      0   363272   7.0000   NaN        S   Mrs             2
# 2  62.0      0      0   240276   9.6875   NaN        Q    Mr             1
# 3  27.0      0      0   315154   8.6625   NaN        S    Mr             1
# 4  22.0      1      1  3101298  12.2875   NaN        S   Mrs             3
#
#   Family_Category  Group_Fare Size_fare
# ...

# %% [markdown]
# ## Age

# %%
test_df1=pd.DataFrame(test_df.groupby('title',as_index=False)['Age'].mean())
test_df1
# Out:
#     title        Age
# 0    Miss  21.774844
# 1      Mr  32.000000
# 2     Mrs  38.903226
# 3    rare  42.000000
# 4   royal   9.939444

# %%
test_df['Age']=test_df.groupby('title')['Age'].transform(lambda x: x.fillna(x.mean()))

# %%
test_df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
def Age_Category(size):
    D=''
    if (size<=5):
        D='Baby'
    elif (size<=13):
        D='Child'
    elif (size<=19):
        D='Junior_Adult'
    elif (size<=38):
        D='Adult'
    elif (size<55):
        D='Senior_Adult'
    else:
        D='Senior_Citizen'
    return D

# %%
test_df['Age_Category']=test_df['Age'].map(Age_Category)

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked title  Family_Group  \
# 0  34.5      0      0   330911   7.8292   NaN        Q    Mr             1
# 1  47.0      1      0   363272   7.0000   NaN        S   Mrs             2
# 2  62.0      0      0   240276   9.6875   NaN        Q    Mr             1
# 3  27.0      0      0   315154   8.6625   NaN        S    Mr             1
# 4  22.0      1      1  3101298  12.2875   NaN        S   Mrs             3
#
# ...

# %%
test_df2=pd.get_dummies(test_df.drop(['Age','PassengerId','Name','Parch','Family_Group','Ticket','Cabin','SibSp','Fare'],axis=1),columns=['Age_Category','Sex','Pclass','title','Embarked','Family_Category','Size_fare'],prefix_sep='_',drop_first=False)

# %%
# test_df4=pd.get_dummies(test_df3,columns=['Age_Category'],prefix_sep='_',drop_first=False)

# %%
test_df2.head()
# Out:
#    Group_Fare  Age_Category_Adult  Age_Category_Baby  Age_Category_Child  \
# 0    7.829200                   1                  0                   0
# 1    3.500000                   0                  0                   0
# 2    9.687500                   0                  0                   0
# 3    8.662500                   1                  0                   0
# 4    4.095833                   1                  0                   0
#
#    Age_Category_Junior_Adult  Age_Category_Senior_Adult  \
# 0                          0                          0
# 1                          0                          1
# 2                          0                          0
# 3                          0                          0
# 4                          0                          0
#
#    Age_Category_Senior_Citizen  Sex_female  Sex_male  Pclass_1  \
# 0                            0           0         1         0
# ...

# %%
# test_df5=test_df4.drop(['PassengerId', 'Name', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare','Family_Group'],axis=1)

# %%
# test_df5.columns

# %%
# train.columns

# %%
# train.head()

# %% [markdown]
# ## Now Using Random_Forest and GradientBoost

# %%
train=data1.drop(['Survived'],axis=1)
train_y=data1['Survived']

# %%
# model.fit(train,train_y)

# %%
# pd.DataFrame(model.predict(test_df5)).head()

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(train,train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=2, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
prediction=pd.DataFrame(clf.predict(test_df2))

# %%
prediction['Survived']=prediction

# %%
prediction.Survived.value_counts()
# Out:
# 0    268
# 1    150
# Name: Survived, dtype: int64

# %%
prediction.to_csv('D:/Titanic_project3.csv')
